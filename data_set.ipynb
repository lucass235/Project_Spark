# %%
import pandas as pd

# %%
df = pd.read_csv('./caso.csv')

# %%
# pegar apenas as 20000 primeiras linhas
newDf = df.head(20001)
newDf
# Out:
#              date state             city place_type  confirmed  deaths  \
# 0      2022-03-27    AP              NaN      state     160328    2122
# 1      2022-03-26    AP              NaN      state     160321    2122
# 2      2022-03-25    AP              NaN      state     160314    2122
# 3      2022-03-24    AP              NaN      state     160301    2122
# 4      2022-03-23    AP              NaN      state     160288    2122
# ...           ...   ...              ...        ...        ...     ...
# 19996  2020-06-12    AC  Rodrigues Alves       city         47       3
# 19997  2020-06-11    AC  Rodrigues Alves       city         47       3
# 19998  2020-06-10    AC  Rodrigues Alves       city         38       3
# 19999  2020-06-09    AC  Rodrigues Alves       city         38       3
# 20000  2020-06-08    AC  Rodrigues Alves       city         36       3
#
#        order_for_place  is_last  estimated_population_2019  \
# ...

# %%
# traduzir colunas
newDf = newDf.rename(columns={'date': 'data', 'state': 'estado', 'city': 'cidade', 'place_type': 'tipo_local', 'confirmed': 'confirmados', 'deaths': 'mortes', 'order_for_place': 'ordem_lugar', 'is_last': 'e_ultimo', 'estimated_population_2019': 'populacao_estimada_2019', 'estimated_population': 'populacao_estimada', 'city_ibge_code': 'codigo_ibge_cidade', 'confirmed_per_100k_inhabitants': 'confirmados_por_100k_habitantes', 'death_rate': 'taxa_mortalidade'})

# %%
newDf
# Out:
#              data estado           cidade tipo_local  confirmados  mortes  \
# 0      2022-03-27     AP              NaN      state       160328    2122
# 1      2022-03-26     AP              NaN      state       160321    2122
# 2      2022-03-25     AP              NaN      state       160314    2122
# 3      2022-03-24     AP              NaN      state       160301    2122
# 4      2022-03-23     AP              NaN      state       160288    2122
# ...           ...    ...              ...        ...          ...     ...
# 19996  2020-06-12     AC  Rodrigues Alves       city           47       3
# 19997  2020-06-11     AC  Rodrigues Alves       city           47       3
# 19998  2020-06-10     AC  Rodrigues Alves       city           38       3
# 19999  2020-06-09     AC  Rodrigues Alves       city           38       3
# 20000  2020-06-08     AC  Rodrigues Alves       city           36       3
#
#        ordem_lugar  e_ultimo  populacao_estimada_2019  populacao_estimada  \
# ...

# %%
# salvar em um novo arquivo csv
open('caso_covid.csv', 'w').write(newDf.to_csv())
# Out:
# 1943537
